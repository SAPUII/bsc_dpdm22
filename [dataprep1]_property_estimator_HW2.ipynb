# %% [markdown]
# <a href="https://colab.research.google.com/github/SAPUII/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
A = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
A.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# #นักประเมินคนที่ 1

# %%
est1 = A[A['ID ผู้ประเมิน']==1]
est1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
et1_conf = plt.hist(est1['ความมั่นใจในการเมินราคาทรัพย์'])

# %%
ret1_score = plt.hist(est1['ให้คะแนนทรัพย์'])
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3], <a list of 4 Text major ticklabel objects>)

# %%
ret1_score
# Out:
# (array([43.,  0.,  0., 54.,  0.,  0.,  2.,  0.,  0.,  1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
est1['ให้คะแนนทรัพย์'].value_counts() #เพื่อนตอบ
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est1.groupby(['ให้คะแนนทรัพย์']).count() #เพื่อนตอบ
# Out:
#                                     ID ผู้ประเมิน  post id  property_type  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                               1        1              1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี             54       54             54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน              43       43             43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                2        2              2
#
#                                     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                                               1           1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                             54          54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                              43          43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                                2           2
#
#                                     ประเมินราคาซื้อ-ขาย  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                                     1
# ...

# %%
est1[est1['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี'].count() #เพื่อนตอบ
# Out:
# ID ผู้ประเมิน                     54
# post id                           54
# property_type                     54
# ความมั่นใจในการเมินราคาทรัพย์     54
# ราคาทรัพย์                        54
# ประเมินราคาซื้อ-ขาย               54
# ปัจจัยในการประเมินราคาซื้อ-ขาย    54
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    54
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
est1.describe()['ประเมินราคาซื้อ-ขาย']
# Out:
# count    1.000000e+02
# mean     3.938500e+06
# std      2.368553e+06
# min      6.000000e+05
# 25%      2.775000e+06
# 50%      3.600000e+06
# 75%      4.500000e+06
# max      1.600000e+07
# Name: ประเมินราคาซื้อ-ขาย, dtype: float64

# %%
est1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# #นักประเมินคนที่ 2

# %%
est2 = A[A['ID ผู้ประเมิน']==2]
est2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# ...

# %%
est2 = A[A['ID ผู้ประเมิน']==2]
print(f'ประเมินทั้งหมด {len(est2)}')
# Out:
# ประเมินทั้งหมด 90

# %%
est2.describe()['ประเมินราคาซื้อ-ขาย']
# Out:
# count    8.900000e+01
# mean     4.153258e+06
# std      2.386901e+06
# min      9.900000e+05
# 25%      2.600000e+06
# 50%      3.900000e+06
# 75%      4.900000e+06
# max      1.700000e+07
# Name: ประเมินราคาซื้อ-ขาย, dtype: float64

# %%
est2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# #เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# #บ้าน

# %%
A = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
A.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %%
est2['ประเมินโดย1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2
# Out:
# <ipython-input-24-b6a3106ea7ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2['ประเมินโดย1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
est2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
est2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# ...

# %%
home= est2[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
home
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2
# 1      2700000.0
# 3      2400000.0
# 5      9000000.0
# 7      3700000.0
# 9      2500000.0
# ..           ...
# 185    5000000.0
# ...

# %%
home.isnull().any()
# Out:
# post id        False
# ราคาทรัพย์     False
# ประเมินโดย1    False
# ประเมินโดย2     True
# dtype: bool

# %%
home_A = home.dropna(subset=['ประเมินโดย2'])
home_A
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0    1200000.0
#
#      ประเมินโดย2
# 1      2700000.0
# 3      2400000.0
# 5      9000000.0
# 7      3700000.0
# 9      2500000.0
# ..           ...
# 185    5000000.0
# ...

# %%
home_A.isnull().any()
# Out:
# post id        False
# ราคาทรัพย์     False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %% [markdown]
# #MAPE ของบ้าน

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mapeA1 = mean_absolute_percentage_error(home_A['ราคาทรัพย์'],home_A['ประเมินโดย1'])
print(mapeA1)
# Out:
# 0.12321512246130807

# %%
mapeA2 = mean_absolute_percentage_error(home_A['ราคาทรัพย์'],home_A['ประเมินโดย2'])
print(mapeA2)
# Out:
# 0.10417687099245776

# %%
mapeA3 = mean_absolute_percentage_error(home_A['ประเมินโดย1'],home_A['ประเมินโดย2'])
print(mapeA3)
# Out:
# 0.13626068116793127

# %%
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์ มีค่า MAPE เท่ากับ {mapeA1}')
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์ มีค่า MAPE เท่ากับ {mapeA2}')
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์ มีค่า MAPE เท่ากับ {mapeA3}')
# Out:
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์ มีค่า MAPE เท่ากับ 0.12321512246130807
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์ มีค่า MAPE เท่ากับ 0.10417687099245776
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์ มีค่า MAPE เท่ากับ 0.13626068116793127

# %% [markdown]
# #ที่ดิน

# %%
B = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
B.head()
# Out:
#    ID ผู้ประเมิน                               post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1              2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2              4  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3              1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4              2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     2800000            1800000.0
# 1                        มั่นใจ     2800000            2000000.0
# 2                        มั่นใจ     2800000            3000000.0
# 3                        มั่นใจ    14900000            8000000.0
# 4                        มั่นใจ    14900000           12000000.0
#
#             ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                             8,000-25,000                        NaN
# ...

# %%
B1 = B[B['ID ผู้ประเมิน']==1]
B1.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 0               1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3               1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6               1  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9               1  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12              1  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                         มั่นใจ     2800000            1800000.0
# 3                         มั่นใจ    14900000            8000000.0
# 6                         มั่นใจ    90000000           18000000.0
# 9                         มั่นใจ    65000000           35000000.0
# 12                        มั่นใจ     3000000            2200000.0
#
#    ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                    8,000-25,000                        NaN
# ...

# %%
B2 = B[B['ID ผู้ประเมิน']==2]
B2.head()
# Out:
#     ID ผู้ประเมิน                               post id property_type  \
# 1               2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4               2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7               2  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10              2  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13              2  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                         มั่นใจ     2800000            2000000.0
# 4                         มั่นใจ    14900000           12000000.0
# 7                         มั่นใจ    90000000           70000000.0
# 10                        มั่นใจ    65000000           60000000.0
# 13                        มั่นใจ     3000000            2500000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 1     ราคาเสนอขาย 7,000-12,0000 บาท/ตารางวา                        NaN
# ...

# %%
B2['ประเมินโดย1'] = B2['post id'].map(B1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
B2
# Out:
# <ipython-input-37-26b4dac4aeb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B2['ประเมินโดย1'] = B2['post id'].map(B1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# ...

# %%
B2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
B2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# ...

# %%
area= B2[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
area
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000    2200000.0
# ..                                     ...         ...          ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000    4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000     500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000    2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000    1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000    2500000.0
#
#      ประเมินโดย2
# 1      2000000.0
# 4     12000000.0
# 7     70000000.0
# 10    60000000.0
# 13     2500000.0
# ..           ...
# 200    4000000.0
# ...

# %%
area.isnull().any()
# Out:
# post id        False
# ราคาทรัพย์     False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %% [markdown]
# #MAPE ของที่ดิน

# %%
mapeB1 = mean_absolute_percentage_error(area['ราคาทรัพย์'],area['ประเมินโดย1'])
print(mapeB1)
# Out:
# 0.41337842594528956

# %%
mapeB2 = mean_absolute_percentage_error(area['ราคาทรัพย์'],area['ประเมินโดย2'])
print(mapeB2)
# Out:
# 0.40761637525700556

# %%
mapeB3 = mean_absolute_percentage_error(area['ประเมินโดย1'],area['ประเมินโดย2'])
print(mapeB3)
# Out:
# 0.7485711748093226

# %%
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeB1}')
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeB2}')
print(f'ความแตกต่างในการประเมินราคาทรัพย์ของนักประเมินคนที่ 1 และ นักประเมินคนที่ 2  มีค่า MAPE เท่ากับ {mapeB3}')
# Out:
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.41337842594528956
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.40761637525700556
# ความแตกต่างในการประเมินราคาทรัพย์ของนักประเมินคนที่ 1 และ นักประเมินคนที่ 2  มีค่า MAPE เท่ากับ 0.7485711748093226

# %% [markdown]
# #คอนโด

# %%
C = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
C.head()
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1   1930000.0            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2   2438000.0            2800000.0    35,000-80,000 บาท/ตารางเมตร
# 3   1600000.0            2300000.0    30,000-80,000 บาท/ตารางเมตร
# 4   1860000.0            1800000.0    30,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                    ให้คะแนนทรัพย์  Unnamed: 9  \
# ...

# %%
C1 = C[C['ID ผู้ประเมิน']==1]
C1.head()
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1   1930000.0            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2   2438000.0            2800000.0    35,000-80,000 บาท/ตารางเมตร
# 3   1600000.0            2300000.0    30,000-80,000 บาท/ตารางเมตร
# 4   1860000.0            1800000.0    30,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                    ให้คะแนนทรัพย์  Unnamed: 9  \
# ...

# %%
C1.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย1'},inplace=True);
C1
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินโดย1 ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0    3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1   1930000.0    2200000.0    50,000-90,000 บาท/ตารางเมตร
# ...

# %%
condo= C1[['post id','ราคาทรัพย์','ประเมินโดย1']]
condo
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย1
# 0     32.0   3500000.0    3500000.0
# 1     36.0   1930000.0    2200000.0
# 2    603.0   2438000.0    2800000.0
# 3   1395.0   1600000.0    2300000.0
# 4   1443.0   1860000.0    1800000.0
# 5   1609.0   1490000.0    1500000.0
# 6   1640.0   1280000.0    1600000.0
# 7   1641.0   4290000.0    2700000.0
# 8   1650.0   1700000.0    1550000.0
# 9   1840.0   3790000.0    2800000.0

# %%
condo.isnull().any()
# Out:
# post id        False
# ราคาทรัพย์     False
# ประเมินโดย1    False
# dtype: bool

# %% [markdown]
# #MAPE ของคอนโด

# %%
mapeC1 = mean_absolute_percentage_error(condo['ราคาทรัพย์'],condo['ประเมินโดย1'])
print(mapeC1)
# Out:
# 0.17349265946250259

# %%
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeC1}')
# Out:
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.17349265946250259

# %% [markdown]
# #ทาวน์โฮม

# %%
D = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
D.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2              1  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4              1  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   1045000.0             700000.0
# 1                        มั่นใจ   1045000.0            1500000.0
# 2                        มั่นใจ    935000.0             700000.0
# 3                        มั่นใจ    935000.0            1500000.0
# 4                        มั่นใจ   3520000.0            3500000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                         NaN
# ...

# %%
D1 = D[D['ID ผู้ประเมิน']==1]
D1.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2              1  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4              1  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 6              1  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 8              1  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   1045000.0             700000.0
# 2                        มั่นใจ    935000.0             700000.0
# 4                        มั่นใจ   3520000.0            3500000.0
# 6                        มั่นใจ   3850000.0            3500000.0
# 8                        มั่นใจ    990000.0            1000000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                         NaN
# ...

# %%
D2 = D[D['ID ผู้ประเมิน']==2]
D2.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5              2  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7              2  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9              2  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   1045000.0            1500000.0
# 3                        มั่นใจ    935000.0            1500000.0
# 5                        มั่นใจ   3520000.0            4000000.0
# 7                        มั่นใจ   3850000.0            3200000.0
# 9                        มั่นใจ    990000.0             800000.0
#
#                ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 1                   ราคาซื้อขาย 1-2 ล้าน/คูหา                         NaN
# ...

# %%
D2['ประเมินโดย1'] = D2['post id'].map(D1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
D2
# Out:
# <ipython-input-54-c41b36af9b6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   D2['ประเมินโดย1'] = D2['post id'].map(D1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# ...

# %%
D2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
D2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# ...

# %%
townhome= D2[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
townhome
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0     700000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0     700000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0    3500000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0    1000000.0
# ..                                     ...         ...          ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0    1000000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0    1500000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0    1600000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0    1600000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0    1700000.0
#
#      ประเมินโดย2
# 1      1500000.0
# 3      1500000.0
# 5      4000000.0
# 7      3200000.0
# 9       800000.0
# ..           ...
# 235    1200000.0
# ...

# %%
townhome.isnull().any()
# Out:
# post id        False
# ราคาทรัพย์     False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %% [markdown]
# #MAPE ของทาวน์โฮม

# %%
mapeD1 = mean_absolute_percentage_error(townhome['ราคาทรัพย์'],townhome['ประเมินโดย1'])
print(mapeD1)
# Out:
# 0.11373507980201533

# %%
mapeD2 = mean_absolute_percentage_error(townhome['ราคาทรัพย์'],townhome['ประเมินโดย2'])
print(mapeD2)
# Out:
# 0.08766742521930593

# %%
mapeD3 = mean_absolute_percentage_error(townhome['ประเมินโดย1'],townhome['ประเมินโดย2'])
print(mapeD3)
# Out:
# 0.1121168528826893

# %%
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeD1}')
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeD2}')
print(f'ความแตกต่างในการประเมินราคาทรัพย์ของนักประเมินคนที่ 1 และ นักประเมินคนที่ 2  มีค่า MAPE เท่ากับ {mapeD3}')
# Out:
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.11373507980201533
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.08766742521930593
# ความแตกต่างในการประเมินราคาทรัพย์ของนักประเมินคนที่ 1 และ นักประเมินคนที่ 2  มีค่า MAPE เท่ากับ 0.1121168528826893

# %% [markdown]
# #อาคารพาณิชย์

# %%
E = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
E.head()
# Out:
#    ID ผู้ประเมิน                             post id          property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2              1  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4              1  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   7000000.0            6000000.0
# 1                        มั่นใจ   7000000.0            8000000.0
# 2                        มั่นใจ  12000000.0           12000000.0
# 3                        มั่นใจ  12000000.0           12000000.0
# 4                        มั่นใจ  22500000.0           13500000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# ...

# %%
E1 = E[E['ID ผู้ประเมิน']==1]
E1.head()
# Out:
#    ID ผู้ประเมิน                             post id          property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2              1  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4              1  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6              1  https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8              1  https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   7000000.0            6000000.0
# 2                        มั่นใจ  12000000.0           12000000.0
# 4                        มั่นใจ  22500000.0           13500000.0
# 6                        มั่นใจ   3500000.0            4000000.0
# 8                        มั่นใจ   3900000.0            2200000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# ...

# %%
E2 = E[E['ID ผู้ประเมิน']==2]
E2.head()
# Out:
#    ID ผู้ประเมิน                             post id          property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5              2  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7              2  https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9              2  https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   7000000.0            8000000.0
# 3                        มั่นใจ  12000000.0           12000000.0
# 5                        มั่นใจ  22500000.0           20000000.0
# 7                        มั่นใจ   3500000.0            4000000.0
# 9                        มั่นใจ   3900000.0            3000000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# ...

# %%
E2['ประเมินโดย1'] = E2['post id'].map(E1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
E2
# Out:
# <ipython-input-64-5c64d4a20fd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E2['ประเมินโดย1'] = E2['post id'].map(E1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
E2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
E2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# ...

# %%
building= E2[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
building
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0    6000000.0    8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0   12000000.0   12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0   13500000.0   20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0    4000000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0    2200000.0    3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0    3600000.0    4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0    2500000.0    2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0    3800000.0    5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0    7000000.0    8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0    8000000.0   10000000.0

# %%
building.isnull().any()
# Out:
# post id        False
# ราคาทรัพย์     False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %% [markdown]
# #MAPE ของอาคารพาณิชย์

# %%
mapeE1 = mean_absolute_percentage_error(building['ราคาทรัพย์'],building['ประเมินโดย1'])
print(mapeE1)
# Out:
# 0.17643894993894996

# %%
mapeE2 = mean_absolute_percentage_error(building['ราคาทรัพย์'],building['ประเมินโดย2'])
print(mapeE2)
# Out:
# 0.11732295482295482

# %%
mapeE3 = mean_absolute_percentage_error(building['ประเมินโดย1'],building['ประเมินโดย2'])
print(mapeE3)
# Out:
# 0.2158208906103643

# %%
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeE1}')
print(f'ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ {mapeE2}')
print(f'ความแตกต่างในการประเมินราคาทรัพย์ของนักประเมินคนที่ 1 และ นักประเมินคนที่ 2  มีค่า MAPE เท่ากับ {mapeE3}')
# Out:
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 1 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.17643894993894996
# ความแตกต่างในการประเมินราคาซื้อ-ขายของนักประเมินคนที่ 2 และ ราคาทรัพย์  มีค่า MAPE เท่ากับ 0.11732295482295482
# ความแตกต่างในการประเมินราคาทรัพย์ของนักประเมินคนที่ 1 และ นักประเมินคนที่ 2  มีค่า MAPE เท่ากับ 0.2158208906103643

# %% [markdown]
# #เฉลยของอาจารย์

# %%
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %%
temp = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.00%
# นักประเมิน คนที่ 2 = 8.52%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.60%
# จำนวนทรัพย์ทั้งหมด 89 ทรัพย์

# %%
temp = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %%
temp = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 16.21%
# นักประเมิน คนที่ 2 = 12.75%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %%
temp = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 25.45%
# นักประเมิน คนที่ 2 = 12.43%
# ความผิดพลาดระหว่างนักประเมินทั้ง 19.28%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# #เขียนฟังก์ชัน ตรวจสอบค่าที่เติม 0 ผิด

# %%
max(10,2)
# Out:
# 10

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %%
check_v(100,1200)
# Out:
# 12.0

# %% [markdown]
# #สร้าง column ใหม่ ลงในตาราง (บ้าน) โดย ค่าใน column คือค่าจาก function check (ราคาตั้งขาย, ราคาประเมินโดย1)

# %% [markdown]
# #HW2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %% [markdown]
# #check บ้าน

# %%
home_A['check1']=home_A.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
home_A
# Out:
# <ipython-input-75-c2985b11955d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_A['check1']=home_A.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# ...

# %%
check1 = list()
for row in home.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินโดย1']))
check1
# Out:
# [1.08,
#  1.1818181818181819,
#  1.18,
#  1.2571428571428571,
#  1.1,
#  1.271111111111111,
#  1.36,
#  1.0153846153846153,
#  1.3684,
#  1.031941031941032,
#  1.0476190476190477,
#  1.1785714285714286,
#  1.0592592592592593,
#  1.188,
#  1.1275,
#  1.1,
#  1.1157142857142857,
#  1.0371428571428571,
#  1.0588235294117647,
#  1.2571428571428571,
#  1.13125,
#  1.0,
#  1.0888888888888888,
#  1.0892333472978635,
#  1.0444444444444445,
#  1.0,
#  1.0434782608695652,
#  1.02,
#  1.25,
#  1.13,
#  1.0714285714285714,
#  1.0,
#  1.0,
#  1.3833333333333333,
#  1.03125,
#  1.1611111111111112,
#  1.0526315789473684,
#  1.5384615384615385,
#  1.0227272727272727,
#  1.1363636363636365,
#  1.1111111111111112,
#  1.1290322580645162,
#  1.1388888888888888,
#  1.0,
#  1.0933333333333333,
#  1.3093125,
#  1.21,
#  1.24,
#  1.1642857142857144,
#  1.1,
#  1.4685314685314685,
#  1.1111111111111112,
#  1.1942857142857144,
#  1.0714285714285714,
#  1.0710526315789475,
#  1.4575,
#  1.046,
#  1.09375,
# ...

# %%
home_A['check2']=home_A.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
home_A
# Out:
# <ipython-input-77-06bda38893a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_A['check2']=home_A.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0    2500000.0
# ..                                     ...         ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0    4500000.0
# ...

# %%
home_A.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# 75       https://nayoo.co/khonkaen/posts/1    390000.0     600000.0
# 177  https://nayoo.co/khonkaen/posts/19450   2100000.0    3200000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0    5200000.0
# 101   https://nayoo.co/khonkaen/posts/6010   2860000.0    4200000.0
# ..                                     ...         ...          ...
# 167   https://nayoo.co/khonkaen/posts/9141   3500000.0    3500000.0
# 51    https://nayoo.co/khonkaen/posts/1149   4000000.0    4000000.0
# 63    https://nayoo.co/khonkaen/posts/2033   1200000.0    1200000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0    4000000.0
# 87    https://nayoo.co/khonkaen/posts/3905   1200000.0    1200000.0
#
#      ประเมินโดย2    check1    check2
# 187    2500000.0  1.800000  1.250000
# 75     1300000.0  1.538462  3.333333
# ...

# %%
home_A.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 75       https://nayoo.co/khonkaen/posts/1    390000.0     600000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0    5000000.0
# 111   https://nayoo.co/khonkaen/posts/6045   2915000.0    2000000.0
# 83    https://nayoo.co/khonkaen/posts/3721   3100000.0    3500000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0    3600000.0
# ..                                     ...         ...          ...
# 169  https://nayoo.co/khonkaen/posts/11264   6500000.0    5600000.0
# 69    https://nayoo.co/khonkaen/posts/2262   3200000.0    3300000.0
# 57    https://nayoo.co/khonkaen/posts/1895   1200000.0    1500000.0
# 37     https://nayoo.co/khonkaen/posts/760   1800000.0    1700000.0
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0    2500000.0
#
#      ประเมินโดย2    check1    check2
# 75     1300000.0  1.538462  3.333333
# 5      9000000.0  1.180000  1.525424
# ...

# %% [markdown]
# #check ที่ดิน

# %%
area['check1']=area.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
area
# Out:
# <ipython-input-81-caeafcf5a41c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   area['check1']=area.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000    2200000.0
# ..                                     ...         ...          ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000    4000000.0
# ...

# %%
area['check2']=area.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
area
# Out:
# <ipython-input-83-1c2721757d6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   area['check2']=area.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000    2200000.0
# ..                                     ...         ...          ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000    4000000.0
# ...

# %%
area.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000    4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000   32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   160000000   14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000   24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000   18000000.0
# ..                                     ...         ...          ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000    4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000    1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000    1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000     650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000    2500000.0
#
#      ประเมินโดย2     check1     check2
# 194   75000000.0  20.000000   1.200000
# 112    2000000.0  12.307692   1.300000
# ...

# %%
area.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 58    https://nayoo.co/khonkaen/posts/9203   160000000   14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000   24000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550    6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000    2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000    1600000.0
# ..                                     ...         ...          ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000    2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000   10000000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000    2800000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000     500000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000   12000000.0
#
#      ประเมินโดย2     check1     check2
# 58    11000000.0  11.428571  14.545455
# 47    18000000.0  10.208333  13.611111
# ...

# %%
area = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
id1 = area[area['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = area[area['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = MAPE(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %%
#เหลือแก้ค่า 0

# %% [markdown]
# #check ทาวน์โฮม

# %%
townhome= D2[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
townhome['check1']=townhome.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
townhome['check2']=townhome.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
townhome
# Out:
# <ipython-input-87-9c724e8deb5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townhome['check1']=townhome.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
# <ipython-input-87-9c724e8deb5b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   townhome['check2']=townhome.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0     700000.0
# ...

# %%
townhome.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0     350000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0    1500000.0
# 132    https://nayoo.co/khonkaen/posts/619   1430000.0     950000.0
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0     700000.0
# 174   https://nayoo.co/khonkaen/posts/3478   2190000.0    1500000.0
# ..                                     ...         ...          ...
# 228  https://nayoo.co/khonkaen/posts/17923   1990000.0    2000000.0
# 167   https://nayoo.co/khonkaen/posts/2829   2490000.0    2500000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0    2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411   3200000.0    3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503   1500000.0    1500000.0
#
#      ประเมินโดย2    check1    check2
# 176     400000.0  6.257143  5.475000
# 180    1500000.0  1.613333  1.613333
# ...

# %%
townhome.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย1  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0     350000.0
# 234  https://nayoo.co/khonkaen/posts/18090   3000000.0    2800000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0    1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0     700000.0
# 225  https://nayoo.co/khonkaen/posts/17742   2500000.0    2200000.0
# ..                                     ...         ...          ...
# 188   https://nayoo.co/khonkaen/posts/8101   3200000.0    3300000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0    2800000.0
# 199  https://nayoo.co/khonkaen/posts/12957   1500000.0    1600000.0
# 151   https://nayoo.co/khonkaen/posts/1978   2500000.0    2700000.0
# 181   https://nayoo.co/khonkaen/posts/6104   2200000.0    2500000.0
#
#      ประเมินโดย2    check1    check2
# 176     400000.0  6.257143  5.475000
# 234    1500000.0  1.071429  2.000000
# ...

# %% [markdown]
# #check อาคารพาณิชย์

# %%
building= E2[['post id','ราคาทรัพย์','ประเมินโดย1','ประเมินโดย2']]
building['check1']=building.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
building['check2']=building.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
building
# Out:
# <ipython-input-90-6131c589c35d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   building['check1']=building.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย1']),axis=1)
# <ipython-input-90-6131c589c35d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   building['check2']=building.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย2']),axis=1)
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2  \
# ...

# %%
building.sort_values(by=['check1'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0    2200000.0    3000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0   13500000.0   20000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0    3600000.0    4000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0    3800000.0    5000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0    6000000.0    8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0    4000000.0    4000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0    8000000.0   10000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0    2500000.0    2100000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0   12000000.0   12000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0    7000000.0    8000000.0
#
#       check1    check2
# 9   1.772727  1.300000
# 5   1.666667  1.125000
# 11  1.333333  1.200000
# ...

# %%
building.sort_values(by=['check2'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย1  ประเมินโดย2  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0    2200000.0    3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0    3600000.0    4000000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0    6000000.0    8000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0    4000000.0    4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0    2500000.0    2100000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0    7000000.0    8000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0   13500000.0   20000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0    8000000.0   10000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0   12000000.0   12000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0    3800000.0    5000000.0
#
#       check1    check2
# 9   1.772727  1.300000
# 11  1.333333  1.200000
# 1   1.166667  1.142857
# ...
