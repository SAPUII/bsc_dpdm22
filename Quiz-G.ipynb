# %% [markdown]
# <a href="https://colab.research.google.com/github/SAPUII/bsc_dpdm22/blob/main/Quiz-G.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/MyDrive/bsc_DPDM_data/อุตุ')

# !pwd #เช็ค paht ที่กำลังทำงานอยู่
# Out:
# /content/drive/.shortcut-targets-by-id/1k6tJcTTv2bKmFz6A5oOWi-sAeTVIQpG4/อุตุ

# %%
# !ls
# Out:
# 'ความกด(เปอร์เซ็นต์)'  'อุณหภูมิต่ำสุด(เซลเซียส)'     'อุณหภูมิจุดน้ำค้าง(เซลเซียส)'
# 'ปริมาณฝน(มิลลิเมตร)'  'อุณหภูมิตุ้มแห้ง(เซลเซียส)'    'จำนวนเมฆ(10ส่วน)'
# 'ความเร็วลม(นอต)'    'ความชื้นสัมพัทธ์(เปอร์เซ็นต์)'

# %% [markdown]
# #ความกด(เปอร์เซ็นต์)

# %%
KH1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4)
NA1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.นครพนม.xlsx',sheet_name='Sheet1',skiprows=4)
SA1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.สกลนคร.xlsx',sheet_name='Sheet1',skiprows=4)
NO1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.หนองคาย.xlsx',sheet_name='Sheet1',skiprows=4)
LO1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.เลย.xlsx',sheet_name='Sheet1',skiprows=4)

# %%
KH1_1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4)
KH2_1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx',sheet_name='Sheet2',skiprows=0)
KH1_1.head()
# Out:
#   Unnamed: 0                Unnamed: 1 Unnamed: 2        1        2        3  \
# 0        1    352201-หนองคาย จ.หนองคาย 2011-10-01  1005.47  1006.65  1007.49
# 1        2    352201-หนองคาย จ.หนองคาย 2011-11-01  1011.79  1010.83  1010.74
# 2        3    352201-หนองคาย จ.หนองคาย 2011-12-01  1011.43  1012.57  1012.28
# 3        1    352201-หนองคาย จ.หนองคาย 2012-01-01  1015.67  1014.11  1012.91
# 4        2    352201-หนองคาย จ.หนองคาย 2012-02-01  1013.26  1012.92  1013.61
#
#          4        5        6        7  ...       23       24       25  \
# 0  1008.28  1009.88  1011.36  1011.17  ...  1010.76  1010.23  1011.34
# 1  1010.71  1010.09  1009.24  1008.03  ...  1014.07  1015.40  1013.95
# 2  1012.97  1013.09  1012.03  1012.05  ...  1012.88  1015.78  1018.56
# 3  1014.06  1015.51  1015.88  1017.72  ...  1010.91  1011.27  1011.65
# 4  1013.18  1011.26  1008.80  1008.16  ...  1005.75  1005.46  1004.80
#
#         26       27       28       29       30       31  Unnamed: 34
# ...

# %%
NA1 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความกด(เปอร์เซ็นต์)/จ.นครพนม.xlsx',skiprows=4)
NA1.head()
# Out:
#   Unnamed: 0                Unnamed: 1 Unnamed: 2        1        2        3  \
# 0        1    352201-หนองคาย จ.หนองคาย 2011-10-01  1006.30  1007.38  1008.07
# 1        2    352201-หนองคาย จ.หนองคาย 2011-11-01  1012.28  1011.23  1011.08
# 2        3    352201-หนองคาย จ.หนองคาย 2011-12-01  1012.15  1013.75  1013.24
# 3        1    352201-หนองคาย จ.หนองคาย 2012-01-01  1016.56  1014.88  1013.41
# 4        2    352201-หนองคาย จ.หนองคาย 2012-02-01  1013.98  1013.75  1014.96
#
#          4        5        6        7  ...       23       24       25  \
# 0  1008.44  1010.51  1011.65  1011.24  ...  1011.09  1010.64  1012.01
# 1  1010.96  1010.57  1009.20  1007.99  ...  1015.49  1016.09  1014.62
# 2  1013.94  1013.35  1012.62  1012.48  ...  1014.23  1017.58  1019.77
# 3  1015.85  1016.94  1017.13  1019.21  ...  1013.13  1012.45  1013.59
# 4  1013.52  1011.85  1008.82  1008.15  ...  1005.76  1005.13  1004.94
#
#         26       27       28       29       30       31  Unnamed: 34
# ...

# %%
KH1_2 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4)
KH1_2.head()
# Out:
#   Unnamed: 0                Unnamed: 1 Unnamed: 2   1   2   3   4   5   6   7  \
# 0        1    381201-ขอนแก่น จ.ขอนแก่น 2011-10-01  83  92  86  80  86  86  83
# 1        2    381201-ขอนแก่น จ.ขอนแก่น 2011-11-01  71  65  68  65  65  68  69
# 2        3    381201-ขอนแก่น จ.ขอนแก่น 2011-12-01  66  61  61  62  61  60  69
# 3        1    381201-ขอนแก่น จ.ขอนแก่น 2012-01-01  65  66  69  63  64  68  65
# 4        2    381201-ขอนแก่น จ.ขอนแก่น 2012-02-01  71  72  71  72  70  68  61
#
#    ...  23  24  25  26  27  28  29  30  31  Unnamed: 34
# 0  ...  73  72  73  69  69  75  71  71  68           79
# 1  ...  65  66  65  67  68  67  67  65   -           68
# 2  ...  63  62  60  60  62  65  66  63  64           63
# 3  ...  80  74  75  71  75  69  70  67  68           69
# 4  ...  58  53  48  57  71  73  68   -   -           65
#
# [5 rows x 35 columns]

# %%
KH1_3 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความเร็วลม(นอต)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4)
KH2_3 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/ความเร็วลม(นอต)/จ.ขอนแก่น.xlsx',sheet_name='Sheet2')
KH1_3.head()
# Out:
#   Unnamed: 0             Unnamed: 1 Unnamed: 2  1  2  3  4  5  6  7  ...  23  \
# 0        1    353301-เลย สกษ. จ.เลย 2011-10-01  3  2  3  2  2  3  4  ...   2
# 1        2    353301-เลย สกษ. จ.เลย 2011-11-01  4  5  3  3  5  2  3  ...   7
# 2        3    353301-เลย สกษ. จ.เลย 2011-12-01  3  4  4  4  4  4  4  ...   5
# 3        1    353301-เลย สกษ. จ.เลย 2012-01-01  4  2  1  4  4  2  4  ...   3
# 4        2    353301-เลย สกษ. จ.เลย 2012-02-01  2  2  3  2  3  1  2  ...   1
#
#    24  25  26  27  28  29  30  31  Unnamed: 34
# 0   3   5   5   5   4   6   4   5     3.354839
# 1   6   5   5   3   1   3   3   -     3.466667
# 2   6   7   6   5   4   4   6   5     4.806452
# 3   3   4   2   2   1   3   4   4     3.129032
# 4   2   3   2   4   3   3   3   -     2.566667
#
# [5 rows x 35 columns]

# %%
KH1_4 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/จำนวนเมฆ(10ส่วน)/จ.ขอนแก่น.xlsx',sheet_name='Sheet1',skiprows=4)
KH2_4 = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/อุตุ/จำนวนเมฆ(10ส่วน)/จ.ขอนแก่น.xlsx',sheet_name='Sheet2')
KH1_4.head()
# Out:
#   Unnamed: 0             Unnamed: 1 Unnamed: 2  1   2   3  4   5   6   7  ...  \
# 0        1    353301-เลย สกษ. จ.เลย 2011-10-01  9  10  10  8  10  10  10  ...
# 1        2    353301-เลย สกษ. จ.เลย 2011-11-01  2   2   2  2   3   6   9  ...
# 2        3    353301-เลย สกษ. จ.เลย 2011-12-01  2   3   4  4   5   8   7  ...
# 3        1    353301-เลย สกษ. จ.เลย 2012-01-01  1   4   7  6   3   1   3  ...
# 4        2    353301-เลย สกษ. จ.เลย 2012-02-01  6   6   8  8   3   3   1  ...
#
#    23  24  25  26  27  28  29  30  31  Unnamed: 34
# 0   2   3   5   3   3   5   4   2   2     6.322581
# 1   6   6   3   2   2   1   3   2   -     3.533333
# 2   5   5   3   3   1   2   1   1   1     3.516129
# 3   6   4   4   3   2   5   6  10  10     5.354839
# 4   1   2   0   1   4   5   1   2   -     2.533333
#
# [5 rows x 35 columns]

# %% [markdown]
# #ความชื้นสัมพัทธ์(เปอร์เซ็นต์)
